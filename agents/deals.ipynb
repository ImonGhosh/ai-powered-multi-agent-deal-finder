# %%
from pydantic import BaseModel
from typing import List, Dict, Self
from bs4 import BeautifulSoup
import re
import feedparser
from tqdm import tqdm
import requests
import time

# %%
feeds = [
    "https://www.dealnews.com/c142/Electronics/?rss=1",
        "https://www.dealnews.com/c39/Computers/?rss=1",
        "https://www.dealnews.com/c238/Automotive/?rss=1",
        "https://www.dealnews.com/f1912/Smart-Home/?rss=1",
        "https://www.dealnews.com/c196/Home-Garden/?rss=1",
       ]

# %%
def extract(html_snippet: str) -> str:
    """
    Use Beautiful Soup to clean up this HTML snippet and extract useful text
    """
    soup = BeautifulSoup(html_snippet, 'html.parser')
    snippet_div = soup.find('div', class_='snippet summary')
    
    if snippet_div:
        description = snippet_div.get_text(strip=True)
        description = BeautifulSoup(description, 'html.parser').get_text()
        description = re.sub('<[^<]+?>', '', description)
        result = description.strip()
    else:
        result = html_snippet
    return result.replace('\n', ' ')

class ScrapedDeal:
    """
    A class to represent a Deal retrieved from an RSS feed
    """
    category: str
    title: str
    summary: str
    url: str
    details: str
    features: str

    def __init__(self, entry: Dict[str, str]):
        """
        Populate this instance based on the provided dict
        """
        self.title = entry['title']
        self.summary = extract(entry['summary'])
        self.url = entry['links'][0]['href']
        stuff = requests.get(self.url).content
        soup = BeautifulSoup(stuff, 'html.parser')
        content = soup.find('div', class_='content-section').get_text()
        content = content.replace('\nmore', '').replace('\n', ' ')
        if "Features" in content:
            self.details, self.features = content.split("Features")
        else:
            self.details = content
            self.features = ""

    def __repr__(self):
        """
        Return a string to describe this deal
        """
        return f"<{self.title}>"

    def describe(self):
        """
        Return a longer string to describe this deal for use in calling a model
        """
        return f"Title: {self.title}\nDetails: {self.details.strip()}\nFeatures: {self.features.strip()}\nURL: {self.url}"

    @classmethod
    def fetch(cls, show_progress : bool = False) -> List[Self]:
        """
        Retrieve all deals from the selected RSS feeds
        """
        deals = []
        feed_iter = tqdm(feeds) if show_progress else feeds
        for feed_url in feed_iter:
            feed = feedparser.parse(feed_url)
            for entry in feed.entries[:10]:
                deals.append(cls(entry))
                time.sleep(0.5)
        return deals

class Deal(BaseModel):
    """
    A class to Represent a Deal with a summary description
    """
    product_description: str
    price: float
    url: str

class DealSelection(BaseModel):
    """
    A class to Represent a list of Deals
    """
    deals: List[Deal]

class Opportunity(BaseModel):
    """
    A class to represent a possible opportunity: a Deal where we estimate
    it should cost more than it's being offered
    """
    deal: Deal
    estimate: float
    discount: float

# %%
feed = feedparser.parse("https://www.dealnews.com/c142/Electronics/?rss=1")
for entry in feed.entries[:10]:
    print(entry)
    time.sleep(0.5)
# Out:
# {'title': 'Samsung Early Black Friday TV & Audio Deals: Up to $1,500 off + free shipping', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': 'Samsung Early Black Friday TV & Audio Deals: Up to $1,500 off + free shipping'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.dealnews.com/Samsung-Early-Black-Friday-TV-Audio-Deals-Up-to-1-500-off-free-shipping/21781861.html?iref=rss-c142'}], 'link': 'https://www.dealnews.com/Samsung-Early-Black-Friday-TV-Audio-Deals-Up-to-1-500-off-free-shipping/21781861.html?iref=rss-c142', 'summary': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/tz8z5ei6kfunx3v0coyb.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="Skip&#x20;the&#x20;Black&#x20;Friday&#x20;lines&#x20;and&#x20;score&#x20;early&#x20;deals&#x20;on&#x20;popular&#x20;models&#x20;like&#x20;The&#x20;Frame,&#x20;as&#x20;well&#x20;as&#x20;soundbars&#x20;and&#x20;bundles.&#x20;We&#x27;ve&#x20;pictured&#x20;the&#x20;Samsung&#x20;75&quot;&#x20;Class&#x20;The&#x20;Frame&#x20;Pro&#x20;LS03FW&#x20;Neo&#x20;QLED&#x20;4K&#x20;Smart&#x20;TV&#x20;for&#x20;&#x24;2,499.99&#x20;-&#x20;a&#x20;&#x24;700&#x20;savings."> <p>Skip the Black Friday lines and score early deals on popular models like The Frame, as well as soundbars and bundles. We\'ve pictured the Samsung 75" Class The Frame Pro LS03FW Neo QLED 4K Smart TV for $2,499.99 - a $700 savings. Shop Now at Samsung </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/tz8z5ei6kfunx3v0coyb.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="Skip&#x20;the&#x20;Black&#x20;Friday&#x20;lines&#x20;and&#x20;score&#x20;early&#x20;deals&#x20;on&#x20;popular&#x20;models&#x20;like&#x20;The&#x20;Frame,&#x20;as&#x20;well&#x20;as&#x20;soundbars&#x20;and&#x20;bundles.&#x20;We&#x27;ve&#x20;pictured&#x20;the&#x20;Samsung&#x20;75&quot;&#x20;Class&#x20;The&#x20;Frame&#x20;Pro&#x20;LS03FW&#x20;Neo&#x20;QLED&#x20;4K&#x20;Smart&#x20;TV&#x20;for&#x20;&#x24;2,499.99&#x20;-&#x20;a&#x20;&#x24;700&#x20;savings."> <p>Skip the Black Friday lines and score early deals on popular models like The Frame, as well as soundbars and bundles. We\'ve pictured the Samsung 75" Class The Frame Pro LS03FW Neo QLED 4K Smart TV for $2,499.99 - a $700 savings. Shop Now at Samsung </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>'}, 'id': 'https://www.dealnews.com/21781861.html?iref=rss-c142', 'guidislink': False, 'published': 'Wed, 05 Nov 2025 12:12:25 -0500', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=5, tm_hour=17, tm_min=12, tm_sec=25, tm_wday=2, tm_yday=309, tm_isdst=0)}
# {'title': 'Best Buy Early Black Friday Deals: Up to 60% off + free shipping', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': 'Best Buy Early Black Friday Deals: Up to 60% off + free shipping'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.dealnews.com/Best-Buy-Early-Black-Friday-Deals-Up-to-60-off-free-shipping/21781831.html?iref=rss-c142'}], 'link': 'https://www.dealnews.com/Best-Buy-Early-Black-Friday-Deals-Up-to-60-off-free-shipping/21781831.html?iref=rss-c142', 'summary': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/pw3erbeapetlrlmdu0vq.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="Best&#x20;Buy&#x20;has&#x20;already&#x20;kicked&#x20;off&#x20;its&#x20;Early&#x20;Black&#x20;Friday&#x20;sale,&#x20;with&#x20;deals&#x20;on&#x20;TVs,&#x20;laptops,&#x20;Apple&#x20;devices,&#x20;and&#x20;more&#x20;that&#x20;are&#x20;marked&#x20;down&#x20;by&#x20;at&#x20;least&#x20;50&#x25;.&#x20;New&#x20;doorbusters&#x20;will&#x20;go&#x20;live&#x20;each&#x20;week&#x20;and&#x20;be&#x20;added&#x20;to&#x20;the&#x20;sale,&#x20;so&#x20;make&#x20;sure&#x20;to&#x20;check&#x20;back&#x20;each&#x20;day.&#x20;Shipping&#x20;is&#x20;free&#x20;for&#x20;My&#x20;Best&#x20;Buy&#x20;members&#x20;&#x28;it&#x27;s&#x20;free&#x20;to&#x20;join&#x29;."> <p>Best Buy has already kicked off its Early Black Friday sale, with deals on TVs, laptops, Apple devices, and more that are marked down by at least 50%. New doorbusters will go live each week and be added to the sale, so make sure to check back each day. Shipping is free for My Best Buy members (it\'s free to join). Shop Now at Best Buy </p> </div>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/pw3erbeapetlrlmdu0vq.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="Best&#x20;Buy&#x20;has&#x20;already&#x20;kicked&#x20;off&#x20;its&#x20;Early&#x20;Black&#x20;Friday&#x20;sale,&#x20;with&#x20;deals&#x20;on&#x20;TVs,&#x20;laptops,&#x20;Apple&#x20;devices,&#x20;and&#x20;more&#x20;that&#x20;are&#x20;marked&#x20;down&#x20;by&#x20;at&#x20;least&#x20;50&#x25;.&#x20;New&#x20;doorbusters&#x20;will&#x20;go&#x20;live&#x20;each&#x20;week&#x20;and&#x20;be&#x20;added&#x20;to&#x20;the&#x20;sale,&#x20;so&#x20;make&#x20;sure&#x20;to&#x20;check&#x20;back&#x20;each&#x20;day.&#x20;Shipping&#x20;is&#x20;free&#x20;for&#x20;My&#x20;Best&#x20;Buy&#x20;members&#x20;&#x28;it&#x27;s&#x20;free&#x20;to&#x20;join&#x29;."> <p>Best Buy has already kicked off its Early Black Friday sale, with deals on TVs, laptops, Apple devices, and more that are marked down by at least 50%. New doorbusters will go live each week and be added to the sale, so make sure to check back each day. Shipping is free for My Best Buy members (it\'s free to join). Shop Now at Best Buy </p> </div>'}, 'id': 'https://www.dealnews.com/21781831.html?iref=rss-c142', 'guidislink': False, 'published': 'Wed, 05 Nov 2025 11:27:02 -0500', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=5, tm_hour=16, tm_min=27, tm_sec=2, tm_wday=2, tm_yday=309, tm_isdst=0)}
# {'title': 'Jackery Early Black Friday Sale: Up to 65% off + up to extra 7% off + free shipping', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': 'Jackery Early Black Friday Sale: Up to 65% off + up to extra 7% off + free shipping'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.dealnews.com/Jackery-Early-Black-Friday-Sale-Up-to-65-off-up-to-extra-7-off-free-shipping/21781797.html?iref=rss-c142'}], 'link': 'https://www.dealnews.com/Jackery-Early-Black-Friday-Sale-Up-to-65-off-up-to-extra-7-off-free-shipping/21781797.html?iref=rss-c142', 'summary': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/lofiezslswlfrrhx54ho.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="Save&#x20;up&#x20;to&#x20;65&#x25;&#x20;on&#x20;a&#x20;wide&#x20;range&#x20;of&#x20;home&#x20;battery&#x20;backups,&#x20;portable&#x20;battery&#x20;packs,&#x20;solar&#x20;panels,&#x20;and&#x20;more&#x20;-&#x20;plus,&#x20;stack&#x20;up&#x20;to&#x20;an&#x20;extra&#x20;7&#x25;&#x20;off&#x20;with&#x20;the&#x20;coupons&#x20;below.&#x20;The&#x20;deals&#x3A;&quot;DEAL3&quot;&#x20;takes&#x20;an&#x20;extra&#x20;3&#x25;&#x20;off&#x20;orders&#x20;of&#x20;&#x24;1,300&quot;DEAL5&quot;&#x20;takes&#x20;an&#x20;extra&#x20;5&#x25;&#x20;off&#x20;orders&#x20;of&#x20;&#x24;1,500&quot;OFFER7&quot;&#x20;takes&#x20;an&#x20;extra&#x20;7&#x25;&#x20;off&#x20;orders&#x20;of&#x20;&#x24;2,500"> <p>Save up to 65% on a wide range of home battery backups, portable battery packs, solar panels, and more - plus, stack up to an extra 7% off with the coupons below. The deals:<ul><li>"DEAL3" takes an extra 3% off orders of $1,300</li><li>"DEAL5" takes an extra 5% off orders of $1,500</li><li>"OFFER7" takes an extra 7% off orders of $2,500</li></ul> Shop Now at Jackery, Inc </p> </div>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/lofiezslswlfrrhx54ho.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="Save&#x20;up&#x20;to&#x20;65&#x25;&#x20;on&#x20;a&#x20;wide&#x20;range&#x20;of&#x20;home&#x20;battery&#x20;backups,&#x20;portable&#x20;battery&#x20;packs,&#x20;solar&#x20;panels,&#x20;and&#x20;more&#x20;-&#x20;plus,&#x20;stack&#x20;up&#x20;to&#x20;an&#x20;extra&#x20;7&#x25;&#x20;off&#x20;with&#x20;the&#x20;coupons&#x20;below.&#x20;The&#x20;deals&#x3A;&quot;DEAL3&quot;&#x20;takes&#x20;an&#x20;extra&#x20;3&#x25;&#x20;off&#x20;orders&#x20;of&#x20;&#x24;1,300&quot;DEAL5&quot;&#x20;takes&#x20;an&#x20;extra&#x20;5&#x25;&#x20;off&#x20;orders&#x20;of&#x20;&#x24;1,500&quot;OFFER7&quot;&#x20;takes&#x20;an&#x20;extra&#x20;7&#x25;&#x20;off&#x20;orders&#x20;of&#x20;&#x24;2,500"> <p>Save up to 65% on a wide range of home battery backups, portable battery packs, solar panels, and more - plus, stack up to an extra 7% off with the coupons below. The deals:<ul><li>"DEAL3" takes an extra 3% off orders of $1,300</li><li>"DEAL5" takes an extra 5% off orders of $1,500</li><li>"OFFER7" takes an extra 7% off orders of $2,500</li></ul> Shop Now at Jackery, Inc </p> </div>'}, 'id': 'https://www.dealnews.com/21781797.html?iref=rss-c142', 'guidislink': False, 'published': 'Wed, 05 Nov 2025 10:35:55 -0500', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=5, tm_hour=15, tm_min=35, tm_sec=55, tm_wday=2, tm_yday=309, tm_isdst=0)}
# {'title': 'Refurb Samsung Galaxy Watch 7 44mm Smartwatch for $106 + free shipping', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': 'Refurb Samsung Galaxy Watch 7 44mm Smartwatch for $106 + free shipping'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.dealnews.com/products/Samsung/Samsung-Galaxy-Watch-7-44-mm-Smartwatch/495284.html?iref=rss-c142'}], 'link': 'https://www.dealnews.com/products/Samsung/Samsung-Galaxy-Watch-7-44-mm-Smartwatch/495284.html?iref=rss-c142', 'summary': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/u8lzx1mtixo7yrkkshfa.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="Apply&#x20;the&#x20;promo&#x20;code&#x20;&quot;TECH4THEM&quot;&#x20;to&#x20;get&#x20;the&#x20;lowest&#x20;price&#x20;we&#x27;ve&#x20;seen&#x20;in&#x20;any&#x20;condition.&#x20;It&#x27;s&#x20;also&#x20;&#x24;174&#x20;less&#x20;than&#x20;you&#x27;d&#x20;pay&#x20;for&#x20;this&#x20;model&#x20;in&#x20;factory&#x20;sealed&#x20;condition.&#x20;A&#x20;one-year&#x20;Allstate&#x20;warranty&#x20;is&#x20;provided."> <p>Apply the promo code "TECH4THEM" to get the lowest price we\'ve seen in any condition. It\'s also $174 less than you\'d pay for this model in factory sealed condition. A one-year Allstate warranty is provided. Buy Now at eBay </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/u8lzx1mtixo7yrkkshfa.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="Apply&#x20;the&#x20;promo&#x20;code&#x20;&quot;TECH4THEM&quot;&#x20;to&#x20;get&#x20;the&#x20;lowest&#x20;price&#x20;we&#x27;ve&#x20;seen&#x20;in&#x20;any&#x20;condition.&#x20;It&#x27;s&#x20;also&#x20;&#x24;174&#x20;less&#x20;than&#x20;you&#x27;d&#x20;pay&#x20;for&#x20;this&#x20;model&#x20;in&#x20;factory&#x20;sealed&#x20;condition.&#x20;A&#x20;one-year&#x20;Allstate&#x20;warranty&#x20;is&#x20;provided."> <p>Apply the promo code "TECH4THEM" to get the lowest price we\'ve seen in any condition. It\'s also $174 less than you\'d pay for this model in factory sealed condition. A one-year Allstate warranty is provided. Buy Now at eBay </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>'}, 'id': 'https://www.dealnews.com/21781790.html?iref=rss-c142', 'guidislink': False, 'published': 'Wed, 05 Nov 2025 10:24:37 -0500', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=5, tm_hour=15, tm_min=24, tm_sec=37, tm_wday=2, tm_yday=309, tm_isdst=0)}
# {'title': 'Philips 55" 4K QLED Roku Smart TV for $260 + free shipping', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': 'Philips 55" 4K QLED Roku Smart TV for $260 + free shipping'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.dealnews.com/products/Philips/Philips-55-4-K-QLED-Roku-Smart-TV/459156.html?iref=rss-c142'}], 'link': 'https://www.dealnews.com/products/Philips/Philips-55-4-K-QLED-Roku-Smart-TV/459156.html?iref=rss-c142', 'summary': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/kbb6jrcrx6mlhiguu0lq.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="It&#x27;s&#x20;&#x24;110&#x20;off&#x20;and&#x20;the&#x20;lowest&#x20;price&#x20;we&#x27;ve&#x20;ever&#x20;seen."> <p>It\'s $110 off and the lowest price we\'ve ever seen. Buy Now at Best Buy </p> </div> <div class="snippet features" title="4K&#x20;resolution&#x20;Dolby&#x20;Vision&#x20;&amp;&#x20;HDR10&#x20;Roku&#x20;Model&#x3A;&#x20;55PUL7973&#x2F;F7"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>4K resolution</li> <li>Dolby Vision & HDR10</li> <li>Roku</li> <li>Model: 55PUL7973/F7</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/kbb6jrcrx6mlhiguu0lq.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="It&#x27;s&#x20;&#x24;110&#x20;off&#x20;and&#x20;the&#x20;lowest&#x20;price&#x20;we&#x27;ve&#x20;ever&#x20;seen."> <p>It\'s $110 off and the lowest price we\'ve ever seen. Buy Now at Best Buy </p> </div> <div class="snippet features" title="4K&#x20;resolution&#x20;Dolby&#x20;Vision&#x20;&amp;&#x20;HDR10&#x20;Roku&#x20;Model&#x3A;&#x20;55PUL7973&#x2F;F7"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>4K resolution</li> <li>Dolby Vision & HDR10</li> <li>Roku</li> <li>Model: 55PUL7973/F7</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>'}, 'id': 'https://www.dealnews.com/21781785.html?iref=rss-c142', 'guidislink': False, 'published': 'Wed, 05 Nov 2025 10:13:57 -0500', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=5, tm_hour=15, tm_min=13, tm_sec=57, tm_wday=2, tm_yday=309, tm_isdst=0)}
# {'title': 'Refurb Unlocked Samsung Galaxy S23 Ultra 512GB Smartphone for $352 + free shipping', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': 'Refurb Unlocked Samsung Galaxy S23 Ultra 512GB Smartphone for $352 + free shipping'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.dealnews.com/products/Samsung/Unlocked-Samsung-Galaxy-S23-Ultra-512-GB-Smartphone/405671.html?iref=rss-c142'}], 'link': 'https://www.dealnews.com/products/Samsung/Unlocked-Samsung-Galaxy-S23-Ultra-512-GB-Smartphone/405671.html?iref=rss-c142', 'summary': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/cuhij3tugz4a97u3ljt7.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="Apply&#x20;promo&#x20;code&#x20;&quot;TECH4THEM&quot;&#x20;to&#x20;get&#x20;the&#x20;best&#x20;price&#x20;we&#x27;ve&#x20;seen&#x20;in&#x20;any&#x20;condition.&#x20;It&#x27;s&#x20;also&#x20;a&#x20;low&#x20;by&#x20;&#x24;78&#x20;compared&#x20;to&#x20;refurbs&#x20;available&#x20;elsewhere.&#x20;A&#x20;one-year&#x20;Allstate&#x20;warranty&#x20;is&#x20;provided."> <p>Apply promo code "TECH4THEM" to get the best price we\'ve seen in any condition. It\'s also a low by $78 compared to refurbs available elsewhere. A one-year Allstate warranty is provided. Buy Now at eBay </p> </div> <div class="snippet features" title="6.8&quot;&#x20;120Hz&#x20;1440x3088&#x20;display&#x20;Snapdragon&#x20;8&#x20;Gen&#x20;2&#x20;Processor&#x20;8GB&#x20;RAM&#x3B;&#x20;256GB&#x20;storage&#x20;200MP&#x20;main&#x20;camera,&#x20;12MP&#x20;front&#x20;camera&#x20;5,000mAh&#x20;battery&#x20;Model&#x3A;&#x20;SM-S918U1"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>6.8" 120Hz 1440x3088 display</li> <li>Snapdragon 8 Gen 2 Processor</li> <li>8GB RAM; 256GB storage</li> <li>200MP main camera, 12MP front camera</li> <li>5,000mAh battery</li> <li>Model: SM-S918U1</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/cuhij3tugz4a97u3ljt7.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="Apply&#x20;promo&#x20;code&#x20;&quot;TECH4THEM&quot;&#x20;to&#x20;get&#x20;the&#x20;best&#x20;price&#x20;we&#x27;ve&#x20;seen&#x20;in&#x20;any&#x20;condition.&#x20;It&#x27;s&#x20;also&#x20;a&#x20;low&#x20;by&#x20;&#x24;78&#x20;compared&#x20;to&#x20;refurbs&#x20;available&#x20;elsewhere.&#x20;A&#x20;one-year&#x20;Allstate&#x20;warranty&#x20;is&#x20;provided."> <p>Apply promo code "TECH4THEM" to get the best price we\'ve seen in any condition. It\'s also a low by $78 compared to refurbs available elsewhere. A one-year Allstate warranty is provided. Buy Now at eBay </p> </div> <div class="snippet features" title="6.8&quot;&#x20;120Hz&#x20;1440x3088&#x20;display&#x20;Snapdragon&#x20;8&#x20;Gen&#x20;2&#x20;Processor&#x20;8GB&#x20;RAM&#x3B;&#x20;256GB&#x20;storage&#x20;200MP&#x20;main&#x20;camera,&#x20;12MP&#x20;front&#x20;camera&#x20;5,000mAh&#x20;battery&#x20;Model&#x3A;&#x20;SM-S918U1"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>6.8" 120Hz 1440x3088 display</li> <li>Snapdragon 8 Gen 2 Processor</li> <li>8GB RAM; 256GB storage</li> <li>200MP main camera, 12MP front camera</li> <li>5,000mAh battery</li> <li>Model: SM-S918U1</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>'}, 'id': 'https://www.dealnews.com/21781782.html?iref=rss-c142', 'guidislink': False, 'published': 'Wed, 05 Nov 2025 10:07:26 -0500', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=5, tm_hour=15, tm_min=7, tm_sec=26, tm_wday=2, tm_yday=309, tm_isdst=0)}
# {'title': 'Refurb Unlocked Samsung Galaxy S22 Plus 256GB Phone for $213 + free shipping', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': 'Refurb Unlocked Samsung Galaxy S22 Plus 256GB Phone for $213 + free shipping'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.dealnews.com/products/Samsung/Samsung-Galaxy-S22-Plus-256-GB-Phone/495552.html?iref=rss-c142'}], 'link': 'https://www.dealnews.com/products/Samsung/Samsung-Galaxy-S22-Plus-256-GB-Phone/495552.html?iref=rss-c142', 'summary': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/h3ezhgg4ma6hgxdzhhee.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="It&#x27;s&#x20;the&#x20;best&#x20;deal&#x20;we&#x27;ve&#x20;seen&#x20;for&#x20;this&#x20;phone&#x20;and&#x20;&#x24;10&#x20;cheaper&#x20;than&#x20;what&#x20;you&#x27;d&#x20;pay&#x20;for&#x20;a&#x20;refurb&#x20;at&#x20;Amazon.&#x20;A&#x20;1-year&#x20;Allstate&#x20;warranty&#x20;applies."> <p>It\'s the best deal we\'ve seen for this phone and $10 cheaper than what you\'d pay for a refurb at Amazon. A 1-year Allstate warranty applies. Buy Now at eBay </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/h3ezhgg4ma6hgxdzhhee.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="It&#x27;s&#x20;the&#x20;best&#x20;deal&#x20;we&#x27;ve&#x20;seen&#x20;for&#x20;this&#x20;phone&#x20;and&#x20;&#x24;10&#x20;cheaper&#x20;than&#x20;what&#x20;you&#x27;d&#x20;pay&#x20;for&#x20;a&#x20;refurb&#x20;at&#x20;Amazon.&#x20;A&#x20;1-year&#x20;Allstate&#x20;warranty&#x20;applies."> <p>It\'s the best deal we\'ve seen for this phone and $10 cheaper than what you\'d pay for a refurb at Amazon. A 1-year Allstate warranty applies. Buy Now at eBay </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>'}, 'id': 'https://www.dealnews.com/21781663.html?iref=rss-c142', 'guidislink': False, 'published': 'Wed, 05 Nov 2025 05:58:25 -0500', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=5, tm_hour=10, tm_min=58, tm_sec=25, tm_wday=2, tm_yday=309, tm_isdst=0)}
# {'title': 'iCandy Bluetooth Selfie Stick for $10 + free shipping', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': 'iCandy Bluetooth Selfie Stick for $10 + free shipping'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.dealnews.com/products/iCandy-Bluetooth-Selfie-Stick/495549.html?iref=rss-c142'}], 'link': 'https://www.dealnews.com/products/iCandy-Bluetooth-Selfie-Stick/495549.html?iref=rss-c142', 'summary': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/xg2fl1hx8snkvgvj4i9v.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="Save&#x20;&#x24;11&#x20;off&#x20;the&#x20;list&#x20;price."> <p>Save $11 off the list price. Buy Now at eBay </p> </div> <div class="snippet features" title="extends&#x20;from&#x20;10&quot;&#x20;to&#x20;38&quot;&#x20;Model&#x3A;&#x20;20031IC71"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>extends from 10" to 38"</li> <li>Model: 20031IC71</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/xg2fl1hx8snkvgvj4i9v.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="Save&#x20;&#x24;11&#x20;off&#x20;the&#x20;list&#x20;price."> <p>Save $11 off the list price. Buy Now at eBay </p> </div> <div class="snippet features" title="extends&#x20;from&#x20;10&quot;&#x20;to&#x20;38&quot;&#x20;Model&#x3A;&#x20;20031IC71"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>extends from 10" to 38"</li> <li>Model: 20031IC71</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>'}, 'id': 'https://www.dealnews.com/21781606.html?iref=rss-c142', 'guidislink': False, 'published': 'Tue, 04 Nov 2025 21:18:14 -0500', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=5, tm_hour=2, tm_min=18, tm_sec=14, tm_wday=2, tm_yday=309, tm_isdst=0)}
# {'title': 'Onn 4K Pro Streaming Device w/ Gemini for $45 + free shipping', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': 'Onn 4K Pro Streaming Device w/ Gemini for $45 + free shipping'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.dealnews.com/products/Onn/4-K-Pro-Streaming-Device-w-Gemini/495540.html?iref=rss-c142'}], 'link': 'https://www.dealnews.com/products/Onn/4-K-Pro-Streaming-Device-w-Gemini/495540.html?iref=rss-c142', 'summary': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/xr8xdmd05nfx7ytgdgv3.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="That&#x27;s&#x20;a&#x20;&#x24;6&#x20;low."> <p>That\'s a $6 low. Buy Now at Walmart </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/xr8xdmd05nfx7ytgdgv3.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="That&#x27;s&#x20;a&#x20;&#x24;6&#x20;low."> <p>That\'s a $6 low. Buy Now at Walmart </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>'}, 'id': 'https://www.dealnews.com/21781589.html?iref=rss-c142', 'guidislink': False, 'published': 'Tue, 04 Nov 2025 17:58:34 -0500', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=4, tm_hour=22, tm_min=58, tm_sec=34, tm_wday=1, tm_yday=308, tm_isdst=0)}
# {'title': 'PWRCard 2,500mAh Slim Power Bank 4-Pack for $10 + free shipping', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': 'PWRCard 2,500mAh Slim Power Bank 4-Pack for $10 + free shipping'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.dealnews.com/PWRCard-2-500-m-Ah-Slim-Power-Bank-4-Pack-for-10-free-shipping/21780867.html?iref=rss-c142'}], 'link': 'https://www.dealnews.com/PWRCard-2-500-m-Ah-Slim-Power-Bank-4-Pack-for-10-free-shipping/21780867.html?iref=rss-c142', 'summary': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/xspct6rhrpo1nqpsrtvq.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="MorningSave&#x20;offers&#x20;the&#x20;PWRCard&#x20;2,500mAh&#x20;Slim&#x20;Power&#x20;Bank&#x20;4-Pack&#x20;for&#x20;&#x24;10&#x20;&#x28;reduced&#x20;from&#x20;&#x24;133&#x29;.&#x20;Plus,&#x20;get&#x20;free&#x20;shipping&#x20;with&#x20;code&#x20;&quot;DEALNEWS&quot;."> <p>MorningSave offers the PWRCard 2,500mAh Slim Power Bank 4-Pack for $10 (reduced from $133). Plus, get free shipping with code "DEALNEWS". Buy Now at MorningSave </p> </div> <div class="snippet features" title="integrated&#x20;USB-C,&#x20;Lightning,&#x20;and&#x20;Micro&#x20;USB&#x20;cables&#x20;LED&#x20;indicators&#x20;show&#x20;you&#x20;how&#x20;much&#x20;charge&#x20;is&#x20;remaining&#x20;works&#x20;with&#x20;both&#x20;Apple&#x20;and&#x20;Android&#x20;devices"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>integrated USB-C, Lightning, and Micro USB cables</li> <li>LED indicators show you how much charge is remaining</li> <li>works with both Apple and Android devices</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://www.dealnews.com/c142/Electronics/?rss=1', 'value': '<img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/xspct6rhrpo1nqpsrtvq.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;" /><div class="snippet summary" title="MorningSave&#x20;offers&#x20;the&#x20;PWRCard&#x20;2,500mAh&#x20;Slim&#x20;Power&#x20;Bank&#x20;4-Pack&#x20;for&#x20;&#x24;10&#x20;&#x28;reduced&#x20;from&#x20;&#x24;133&#x29;.&#x20;Plus,&#x20;get&#x20;free&#x20;shipping&#x20;with&#x20;code&#x20;&quot;DEALNEWS&quot;."> <p>MorningSave offers the PWRCard 2,500mAh Slim Power Bank 4-Pack for $10 (reduced from $133). Plus, get free shipping with code "DEALNEWS". Buy Now at MorningSave </p> </div> <div class="snippet features" title="integrated&#x20;USB-C,&#x20;Lightning,&#x20;and&#x20;Micro&#x20;USB&#x20;cables&#x20;LED&#x20;indicators&#x20;show&#x20;you&#x20;how&#x20;much&#x20;charge&#x20;is&#x20;remaining&#x20;works&#x20;with&#x20;both&#x20;Apple&#x20;and&#x20;Android&#x20;devices"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>integrated USB-C, Lightning, and Micro USB cables</li> <li>LED indicators show you how much charge is remaining</li> <li>works with both Apple and Android devices</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>'}, 'id': 'https://www.dealnews.com/21780867.html?iref=rss-c142', 'guidislink': False, 'published': 'Mon, 03 Nov 2025 03:35:56 -0500', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=3, tm_hour=8, tm_min=35, tm_sec=56, tm_wday=0, tm_yday=307, tm_isdst=0)}
