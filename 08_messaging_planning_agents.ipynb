# %% [markdown]
# # AI Powered Multi-Agent Deal Finder :
#
# This notebook creates below -
#
# The **Messaging Agent** to send push notifications
#
# The **Planning Agent** to coordinate activities
#
# For the Push Notification, we will be using a nifty platform called Pushover.
# We need to set up a free account and add 2 tokens to your `.env` file:
#
# ```
# PUSHOVER_USER=xxx
# PUSHOVER_TOKEN=xxx
# ```

# %%
from dotenv import load_dotenv
from agents.messaging_agent import MessagingAgent

# %%
load_dotenv(override=True)
DB = "products_vectorstore"

# %%
agent = MessagingAgent()

# %%
agent.push("MASSIVE NEWS!!!")

# %%
import chromadb
DB = "products_vectorstore"
client = chromadb.PersistentClient(path=DB)
collection = client.get_or_create_collection('products')
from agents.planning_agent import PlanningAgent

# %%
# Planner Agent returns a list of "Opportunities", whose structure is defined in deals.py (Opportunity Class)
# This opportunity contains the deal object (product description, price, url), estimated price (using ensemble model) and discount
# Opportunity is just a json structured output, returned by the planner agent
planner = PlanningAgent(collection)

# %%
planner.plan()
